# %%
import numpy as np
from cost_functions import V_a, gradV_a, V_b, gradV_b, V_c, gradV_c
import matplotlib.pyplot as plt
from utils import visualize_optimization

# %%
x = np.linspace(-3, 3)
y = np.linspace(-3, 3)
xg, yg = np.meshgrid(x, y)

X = np.array([xg,yg])
z = V_b(X)

fig = plt.figure(figsize=(20,6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xg, yg, z,rstride=1, cstride=1,
                       cmap=plt.cm.jet, linewidth=0, antialiased=False)

ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('V(x)')
ax.set_title('Cost Function B')
# Out:
# Text(0.5, 0.92, 'Cost Function B')

# %%
def V_c(x, vis = False):
    if x.shape[0] != 2:
        raise ValueError('X must have dimension 2.')
    x1, x2 = x[0], x[1]
    a = 1
    b = np.array([1,2])
    C = np.array([[12, 3],
                  [3, 10]])
    d = 10*np.log(1 + x1**4)*np.sin(100*x1)+10*np.log(1 + x2**4)*np.cos(100*x2) 
    print(x.shape)  
    if vis: 
        vis = np.zeros([x.shape[1], x.shape[2]])
        for i in range(x1.shape[0]):
            for j in range(x1.shape[1]):
                d = 10*np.log(1 + x1[i,j]**4)*np.sin(100*x1[i,j])+10*np.log(1 + x2[i,j]**4)*np.cos(100*x2[i,j]) 
                vis[i,j] = (a + b@x[:,i,j] + 0.5*x[:,i,j] @ (C @ x[:,i,j]) + d)
        V = np.array(vis)
    else: 
        V = a + b@x + 0.5*x @ (C @ x) + d
    return  V

# %%
x = np.linspace(-5, 5)
y = np.linspace(-5, 5)
xg, yg = np.meshgrid(x, y)

X = np.array([xg,yg])
z = V_c(X, vis = True)

fig = plt.figure(figsize=(20,6))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(xg, yg, z,rstride=1, cstride=1,
                       cmap=plt.cm.jet, linewidth=0, antialiased=False)

ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('V(x)')
ax.set_title('Cost Function C')
plt.show()
# Out:
# (2, 50, 50)
